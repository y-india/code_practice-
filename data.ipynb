# %%
import pandas as pd
import numpy as np

# %%
fg = pd.read_csv("fear_greed_index.csv")
trades = pd.read_csv("historical_data.csv")

# %%
fg.sample(10)
# Out:
#        timestamp  value classification        date
# 2208  1708493400     78  Extreme Greed  2024-02-21
# 1285  1628746200     70          Greed  2021-08-12
# 1221  1623216600     14   Extreme Fear  2021-06-09
# 188   1533965400     18   Extreme Fear  2018-08-11
# 780   1585114200     13   Extreme Fear  2020-03-25
# 1513  1648445400     60          Greed  2022-03-28
# 1971  1688016600     54        Neutral  2023-06-29
# 1721  1666416600     20   Extreme Fear  2022-10-22
# 2026  1692768600     37           Fear  2023-08-23
# 2136  1702272600     74          Greed  2023-12-11

# %%
trades.sample(10)
# Out:
#                                            Account     Coin  Execution Price  \
# 208649  0x271b280974205ca63b716753467d5a371de622ab      SOL          144.600
# 207927  0x271b280974205ca63b716753467d5a371de622ab     HYPE           17.808
# 39514   0xb1231a4a2dd02f2276fa3c5e2a2f3436e6bfed23      ETH         2260.700
# 118185  0x8170715b3b381dffb7062c0298972d4727a0a63b  MELANIA            0.418
# 2100    0x513b8629fe877bb581bf244e326a047b249c4ff1     @107           18.072
# 77079   0xbaaaf6571ab7d571043ff1e313a9609a10637864     HYPE           13.204
# 21733   0x4f93fead39b70a1824f981a54d4e55b278e9f760      ETH         3177.100
# 70157   0xbaaaf6571ab7d571043ff1e313a9609a10637864     HYPE           20.053
# 105054  0x8477e447846c758f5a675856001ea72298fd9cb5      ETH         3095.000
# 146392  0x7f4f299f74eec87806a830e3caa9afa5f2b9db8f      ETH         1665.400
#
#         Size Tokens  Size USD  Side     Timestamp IST  Start Position  \
# ...

# %%
trades.columns
# Out:
# Index(['Account', 'Coin', 'Execution Price', 'Size Tokens', 'Size USD', 'Side',
#        'Timestamp IST', 'Start Position', 'Direction', 'Closed PnL',
#        'Transaction Hash', 'Order ID', 'Crossed', 'Fee', 'Trade ID',
#        'Timestamp'],
#       dtype='object')

# %%
counts = trades['Account'].value_counts()
print(counts)
# Out:
# Account
# 0xbee1707d6b44d4d52bfe19e41f8a828645437aab    40184
# 0xbaaaf6571ab7d571043ff1e313a9609a10637864    21192
# 0xa0feb3725a9335f49874d7cd8eaad6be45b27416    15605
# 0x8477e447846c758f5a675856001ea72298fd9cb5    14998
# 0xb1231a4a2dd02f2276fa3c5e2a2f3436e6bfed23    14733
# 0x28736f43f1e871e6aa8b1148d38d4994275d72c4    13311
# 0x513b8629fe877bb581bf244e326a047b249c4ff1    12236
# 0x75f7eeb85dc639d5e99c78f95393aa9a5f1170d4     9893
# 0x47add9a56df66b524d5e2c1993a43cde53b6ed85     8519
# 0x4f93fead39b70a1824f981a54d4e55b278e9f760     7584
# 0x23e7a7f8d14b550961925fbfdaa92f5d195ba5bd     7280
# 0xb899e522b5715391ae1d4f137653e7906c5e2115     4838
# 0x8170715b3b381dffb7062c0298972d4727a0a63b     4601
# 0x4acb90e786d897ecffb614dc822eb231b4ffb9f4     4356
# 0x083384f897ee0f19899168e3b1bec365f52a9012     3818
# 0x271b280974205ca63b716753467d5a371de622ab     3809
# 0x39cef799f8b69da1995852eea189df24eb5cae3c     3589
# 0x2c229d22b100a7beb69122eed721cee9b24011dd     3239
# ...

# %%
# Number of unique values in 'Account' column 
unique_count = trades['Account'].nunique() 
print(unique_count)

# The dataset contains 32 unique trading accounts, 
# which we treat as individual traders for the purpose of analysis.
# Out:
# 32

# %%
fg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2644 entries, 0 to 2643
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       2644 non-null   int64
#  1   value           2644 non-null   int64
#  2   classification  2644 non-null   object
#  3   date            2644 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 82.8+ KB

# %%
trades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  object
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
# ...

# %%
print(fg.isnull().sum().sum())
print(trades.isnull().sum().sum())

# there is no NAN(null) value
# Out:
# 0
# 0

# %%
# Loop through each column and print unique values 
for col in trades.columns:
        
    unique_count = trades[col].nunique() 
    print("-" * 100)
    print(f"Column: {col}") 
    print(f"Unique values ({unique_count}): {unique_vals}") 
    print("-" * 100)


print(f"\n\n\n\n\n")


for col in fg.columns:
    unique_vals = fg[col].unique()
    unique_count = fg[col].nunique() 
    print("-" * 100)
    print(f"Column: {col}") 
    print(f"Unique values ({unique_count}): {unique_vals}") 
    print("-" * 100)



"""
# loop insights 
* Dataset mein 32 unique accounts hain. Har account ko ek trader maana gaya hai. 
Sample chhota hai, isliye results limited scope ke hain.

* Coins bahut zyada hain, isliye coin wise analysis useful nahi hoga. Is assignment ka focus trader 
behavior par hona chahiye.

* Raw trade rows decision ko show nahi karti. Ek order ke andar multiple executions hain, 
isliye data ko aggregate karna zaroori hai.

* Direction column clean nahi hai kyunki isme system actions jaise liquidation aur settlement bhi 
include hain. Behavior samajhne ke liye BUY aur SELL zyada reliable hain.

* Closed PnL zyada tar zero hai, iska matlab PnL trade level par nahi dikhta. PnL ko higher level par jod kar dekhna hoga.

* Crossed orders clearly dikh rahe hain, jo aggressive execution ko show karte hain, especially high volatility ke time.

* Fear Greed Index daily hota hai, isliye trades ko date ke through sentiment se jodna sahi approach hai.
"""
# Out:
# ----------------------------------------------------------------------------------------------------
# Column: Account
# Unique values (32): ['0xae5eacaf9c6b9111fd53034a602c192a04e082ed'
#  '0x72c6a4624e1dffa724e6d00d64ceae698af892a0'
#  '0x513b8629fe877bb581bf244e326a047b249c4ff1'
#  '0x083384f897ee0f19899168e3b1bec365f52a9012'
#  '0x430f09841d65beb3f27765503d0f850b8bce7713'
#  '0x8381e6d82f1affd39a336e143e081ef7620a3b7f'
#  '0x4f93fead39b70a1824f981a54d4e55b278e9f760'
#  '0x75f7eeb85dc639d5e99c78f95393aa9a5f1170d4'
#  '0x420ab45e0bd8863569a5efbb9c05d91f40624641'
#  '0xb1231a4a2dd02f2276fa3c5e2a2f3436e6bfed23'
#  '0x23e7a7f8d14b550961925fbfdaa92f5d195ba5bd'
#  '0x6d6a4b953f202f8df5bed40692e7fd865318264a'
#  '0xbaaaf6571ab7d571043ff1e313a9609a10637864'
#  '0xaf40fdc468c30116bd3307bcbf4a451a7ebf1deb'
#  '0x3998f134d6aaa2b6a5f723806d00fd2bbbbce891'
#  '0xa0feb3725a9335f49874d7cd8eaad6be45b27416'
#  '0x8477e447846c758f5a675856001ea72298fd9cb5'
# ...
